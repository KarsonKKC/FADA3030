# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass

openai.api_key = getpass()

# %%
df = pd.read_csv("material list.csv")
df.head(10)
# Out:
#                         Prompt                       Output Functional unit  \
# 0                     Default                           NaN             NaN
# 1                Default Roof                           NaN             NaN
# 2                  Phase-Demo                           NaN             NaN
# 3                  Phase-Temp                           NaN             NaN
# 4        Default Light Source                           NaN             NaN
# 5                System-Zones                           NaN             NaN
# 6                      Copper                       Copper               kg
# 7   Polyvinyl Chloride, Rigid    Polyvinyl Chloride, Rigid               m²
# 8               Steel, Carbon                           NaN             NaN
# 9                   Phase-New                           NaN             NaN
#
#   Embodied GHG  Density                                   Link Source  \
# ...

# %%
dfc1 = df.iloc[:, 0]
print(dfc1)
# Out:
# 0                    Default
# 1               Default Roof
# 2                 Phase-Demo
# 3                 Phase-Temp
# 4       Default Light Source
#                 ...
# 224                    Water
# 225            Wood Flooring
# 226               Wood Shake
# 227                     Zinc
# 228        Plasterboard (Cox)
# Name: Prompt, Length: 229, dtype: object

# %%
df1 = pd.read_csv('EPiC Database 2019.csv')
df1.head(10)
df1mat = df1.iloc[:, 2]
df1mat.head(20)
# Out:
# 0     Citation: Crawford, R.H., Stephan, A. and Prid...
# 1     Full database: https://doi.org/10.26188/5dc228...
# 2          Further information: www.epicdatabase.com.au
# 3                  License: Creative Commons (by-nc-nd)
# 4                                              Material
# 5                                        Concrete block
# 6                    Concrete block - 390 × 190 × 90 mm
# 7                   Concrete block - 390 × 190 × 140 mm
# 8                   Concrete block - 390 × 190 × 190 mm
# 9                                         Cement mortar
# 10                                      Portland cement
# 11                    Autoclaved aerated concrete (AAC)
# 12                       AAC block - 600 × 200 × 100 mm
# 13                       AAC block - 600 × 200 × 150 mm
# 14                       AAC block - 600 × 200 × 200 mm
# 15                                      Concrete 20 MPa
# 16                        Concrete 20 MPa - 30% fly ash
# ...
